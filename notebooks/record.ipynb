# %% [markdown]
# ReliefF record
#   ReliefF selection   : 44,924 → 500 features
#   Selected features saved → relieff_out/relieff_selected_features_fold1.csv
#   k=50   | feat=50    | F1=0.7229 | ACC=0.7926 | AUC=0.9605
#   k=100  | feat=100   | F1=0.7408 | ACC=0.8148 | AUC=0.9414
#   k=200  | feat=200   | F1=0.7268 | ACC=0.8074 | AUC=0.9504
#   k=500  | feat=500   | F1=0.7035 | ACC=0.7778 | AUC=0.9645

# %% [markdown]
# SNR record
#   k=10   | feat=98    | ACC=0.8222 | F1=0.7834 | P=0.7558 | R=0.8546 | AUC=0.9725
#   k=20   | feat=198   | ACC=0.7778 | F1=0.7361 | P=0.6957 | R=0.8361 | AUC=0.9517
#   k=30   | feat=295   | ACC=0.8074 | F1=0.7522 | P=0.7234 | R=0.8088 | AUC=0.9715
#   k=40   | feat=390   | ACC=0.8222 | F1=0.7656 | P=0.7321 | R=0.8170 | AUC=0.9599
#   k=50   | feat=486   | ACC=0.8000 | F1=0.7410 | P=0.7072 | R=0.8223 | AUC=0.9459

# %% [markdown]
# mMRM record

# %% [markdown]
# L1 record

# %% [markdown]
# Fisher record

# %% [markdown]
# ELMO record
